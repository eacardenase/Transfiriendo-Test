# %% [markdown]
# Descripción
# # Conjunto de datos públicos brasileños de comercio electrónico de Olist
# ***
# ¡Bienvenido! Este es un conjunto de datos públicos de comercio electrónico brasileño de pedidos realizados en Olist Store. El conjunto de datos tiene información de 100k pedidos de 2016 a 2018 realizados en múltiples mercados en Brasil. Sus características permiten ver un pedido desde múltiples dimensiones: desde el estado del pedido, el precio, el pago y el desempeño del flete hasta la ubicación del cliente, los atributos del producto y finalmente las reseñas escritas por los clientes. También publicamos un conjunto de datos de geolocalización que relaciona los códigos postales brasileños con las coordenadas lat / lng.
#
# Estos son datos comerciales reales, se han anonimizado y las referencias a las empresas y socios en el texto de revisión se han reemplazado con los nombres de las grandes casas de Game of Thrones.
#
# # Join it With the Marketing Funnel by Olist
# También hemos lanzado un conjunto de datos de embudo de marketing https://www.kaggle.com/olistbr/marketing-funnel-olist/home ¡Puede unir ambos conjuntos de datos y ver un pedido desde la perspectiva de marketing ahora!
#
# Las instrucciones para unirse están disponibles en este Kernel https://www.kaggle.com/andresionek/joining-marketing-funnel-with-brazilian-e-commerce.
#
# # Contexto
# Este conjunto de datos fue proporcionado generosamente por Olist, la tienda por departamentos más grande de los mercados brasileños. Olist conecta pequeñas empresas de todo Brasil con canales sin problemas y con un solo contrato. Esos comerciantes pueden vender sus productos a través de Olist Store y enviarlos directamente a los clientes mediante los socios logísticos de Olist. Vea más en nuestro sitio web: www.olist.com
#
# Después de que un cliente compra el producto en Olist Store, un vendedor recibe una notificación para cumplir con ese pedido. Una vez que el cliente recibe el producto, o vence la fecha estimada de entrega, el cliente recibe una encuesta de satisfacción por correo electrónico donde puede dar una nota por la experiencia de compra y anotar algunos comentarios.
#
# # Atención
# 1. Un pedido puede tener varios artículos.
# 2. Cada artículo puede ser realizado por un vendedor distinto.
# 3. Todo el texto que identifica tiendas y socios fue reemplazado por los nombres de las grandes casas de Game of Thrones.
#
#
# # Ejemplo de una lista de productos en un mercado

# %% [markdown]
# ![image](https://i.imgur.com/JuJMns1.png)

# %% [markdown]
# # Data Schema
# Los datos se dividen en varios conjuntos de datos para una mejor comprensión y organización. Consulte el siguiente esquema de datos cuando trabaje con él:

# %% [markdown]
# ![image](https://i.imgur.com/HRhd2Y0.png)

# %% [markdown]
# # Classified Dataset
# Anteriormente habíamos publicado un conjunto de datos clasificados, pero lo eliminamos en la Versión 6. Tenemos la intención de publicarlo nuevamente como un nuevo conjunto de datos con un nuevo esquema de datos. Si bien no lo terminamos, puede usar el conjunto de datos clasificados disponible en la Versión 5 o anterior.
#
# # Inspiration
# Aquí hay algo de inspiración para los posibles resultados de este conjunto de datos.
#
# # NLP:
#
# Este conjunto de datos ofrece un entorno supremo para analizar el texto de las reseñas a través de sus múltiples dimensiones.
#
# # Clustering:
#
# Algunos clientes no escribieron una reseña. Pero, ¿por qué están felices o enojados?
#
# # Sales Prediction:
#
# Con la información de la fecha de compra, podrá predecir las ventas futuras.
#
# # Delivery Performance:
#
# También podrá trabajar en el desempeño de la entrega y encontrar formas de optimizar los tiempos de entrega.
#
# # Product Quality:
#
# Disfrute descubriendo las categorías de productos que son más propensas a la insatisfacción del cliente.
#
# # Feature Engineering:
#
# Cree características a partir de este rico conjunto de datos o adjúntele información pública externa.
#
# # Acknowledgements
#
# Gracias a Olist por publicar este conjunto de datos.

# %% [markdown]
# # Tareas
#
# Realizar
# * Código mantenible y código limpio
# * Analisis Exploratorio de Datos
# * Interpretación del problema
# * Ingeniería de características
# * Series temporales
# * Modelos
# * Predicción de ventas
# * Optimización entregas pedidos
# * Clasificación
# * Procesamiento de lenguaje Natural
# * Dedicación
# * Exposición
# * Presentación y claridad
#
# # Entregables
#
# Elegir la herramienta con la que se sientan mejor
#
# * Word
# * Power Point
# * Excel
# * Kaggle
# * Colab
# * Streamlit, bokeh, dash, heroku
# * Spyder
# * Jupyter Lab

# %% [markdown]
# # Planteamiento del problema
#
# ## 1. AS
#
# ### Asdas
#
# asdansjnfd

# %%
cd ..
# Out:
# /home/eacardenase/Documents/Trabajo/Transfiriendo-Test

# %%
cd Data
# Out:
# /home/eacardenase/Documents/Trabajo/Transfiriendo-Test/Data

# %%
# ls

# %%
import pandas as pd
import numpy as np
import os

# %%
print("### Bases de Datos proporcionadas por Olist ###")
print("\n",('-'*45),"\n")
for indice, archivo in enumerate(os.listdir("/home/eacardenase/Documents/Trabajo/\
Transfiriendo-Test/Data")):
    print(indice + 1, "-", archivo)
# Out:
# ### Bases de Datos proporcionadas por Olist ###
#
#  ---------------------------------------------
#
# 1 - olist_customers_dataset.csv
# 2 - olist_order_items_dataset.csv
# 3 - olist_geolocation_dataset.csv
# 4 - olist_order_reviews_dataset.csv
# 5 - product_category_name_translation.csv
# 6 - olist_sellers_dataset.csv
# 7 - olist_closed_deals_dataset.csv
# 8 - olist_marketing_qualified_leads_dataset.csv
# 9 - olist_order_payments_dataset.csv
# 10 - olist_products_dataset.csv
# 11 - olist_orders_dataset.csv

# %%
customers = pd.read_csv("olist_customers_dataset.csv")
geolocation = pd.read_csv("olist_geolocation_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
order_payments = pd.read_csv("olist_order_payments_dataset.csv")
order_reviews = pd.read_csv("olist_order_reviews_dataset.csv")
orders = pd.read_csv("olist_orders_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
product_translation = pd.read_csv("product_category_name_translation.csv")
closed_deals = pd.read_csv("olist_closed_deals_dataset.csv")
mql = pd.read_csv("olist_marketing_qualified_leads_dataset.csv")

# %% [markdown]
# # Natural Language Processing

# %%
import re
from nltk.corpus import stopwords
stopwords_ptg = stopwords.words("portuguese")

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
# Realizamos una copia del dataset original para efectuar los analisis y conservar la informacion
reviews = order_reviews.copy()
reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4                  NaN
# 1                 5                  NaN
# 2                 5                  NaN
# 3                 5                  NaN
# 4                 5                  NaN
# ...             ...                  ...
# 99995             5                  NaN
# 99996             5                  NaN
# 99997             4                  NaN
# 99998             1                  NaN
# 99999             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99995                                                NaN  2017-12-09 00:00:00
# 99996  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99997                                                NaN  2018-07-01 00:00:00
# 99998  Solicitei a compra de uma capa de retrovisor c...  2017-12-15 00:00:00
# 99999  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99995     2017-12-11 20:06:42
# 99996     2018-03-23 09:10:43
# 99997     2018-07-02 12:59:13
# 99998     2017-12-16 01:29:43
# 99999     2017-07-03 21:01:49
#
# [100000 rows x 7 columns]

# %%
# Eliminar las filas de la columna review en donde se presenten NaN
reviews = reviews.dropna(subset=["review_comment_message"])

# %%
reviews
# Out:
#                               review_id                          order_id  \
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 9      8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 12     4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 15     3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# ...                                 ...                               ...
# 99983  df5fae90e85354241d5d64a8955b2b09  509b86c65fe4e2ad5b96408cfef9755e
# 99990  a709d176f59bc3af77f4149c96bae357  d5cb12269711bd1eaf7eed8fd32a7c95
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 3                 5                  NaN
# 4                 5                  NaN
# 9                 4            recomendo
# 12                4                  NaN
# 15                5      Super recomendo
# ...             ...                  ...
# 99983             5                  NaN
# 99990             3                  NaN
# 99996             5                  NaN
# 99998             1                  NaN
# 99999             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# 9      aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 12       Mas um pouco ,travando...pelo valor ta Boa.\r\n  2018-02-16 00:00:00
# 15     Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
# ...                                                  ...                  ...
# 99983  Entregou dentro do prazo. O produto chegou em ...  2018-02-07 00:00:00
# 99990  O produto não foi enviado com NF, não existe v...  2018-05-19 00:00:00
# 99996  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99998  Solicitei a compra de uma capa de retrovisor c...  2017-12-15 00:00:00
# 99999  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# 9         2018-05-23 16:45:47
# 12        2018-02-20 10:52:22
# 15        2018-05-24 03:00:01
# ...                       ...
# 99983     2018-02-19 19:47:23
# 99990     2018-05-20 21:51:06
# 99996     2018-03-23 09:10:43
# 99998     2017-12-16 01:29:43
# 99999     2017-07-03 21:01:49
#
# [41753 rows x 7 columns]

# %%
print(f"Contamos con un total de {len(reviews)} datos sobre las reviews de los \
clientes para realizar NLP.")
# Out:
# Contamos con un total de 41753 datos sobre las reviews de los clientes para realizar NLP.

# %%
duplicados = round(sum(reviews.duplicated("review_id"))/len(reviews)*100, 2)
print(f" Hay {duplicados}% de reviews duplicados basados en los id.")
# Out:
#  Hay 0.77% de reviews duplicados basados en los id.

# %%
# Eliminacion de duplicados basado en los id
reviews = reviews.drop_duplicates("review_id")
reviews = reviews.reset_index(drop=True)

# %%
reviews
# Out:
#                               review_id                          order_id  \
# 0      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 1      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 2      8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3      4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 4      3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# ...                                 ...                               ...
# 41426  df5fae90e85354241d5d64a8955b2b09  509b86c65fe4e2ad5b96408cfef9755e
# 41427  a709d176f59bc3af77f4149c96bae357  d5cb12269711bd1eaf7eed8fd32a7c95
# 41428  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 41429  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 41430  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 5                  NaN
# 1                 5                  NaN
# 2                 4            recomendo
# 3                 4                  NaN
# 4                 5      Super recomendo
# ...             ...                  ...
# 41426             5                  NaN
# 41427             3                  NaN
# 41428             5                  NaN
# 41429             1                  NaN
# 41430             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 1      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# 2      aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 3        Mas um pouco ,travando...pelo valor ta Boa.\r\n  2018-02-16 00:00:00
# 4      Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
# ...                                                  ...                  ...
# 41426  Entregou dentro do prazo. O produto chegou em ...  2018-02-07 00:00:00
# 41427  O produto não foi enviado com NF, não existe v...  2018-05-19 00:00:00
# 41428  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 41429  Solicitei a compra de uma capa de retrovisor c...  2017-12-15 00:00:00
# 41430  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2017-04-21 22:02:06
# 1         2018-03-02 10:26:53
# 2         2018-05-23 16:45:47
# 3         2018-02-20 10:52:22
# 4         2018-05-24 03:00:01
# ...                       ...
# 41426     2018-02-19 19:47:23
# 41427     2018-05-20 21:51:06
# 41428     2018-03-23 09:10:43
# 41429     2017-12-16 01:29:43
# 41430     2017-07-03 21:01:49
#
# [41431 rows x 7 columns]

# %%
reviews_cleaned = reviews["review_comment_message"]
reviews_cleaned.head()
# Out:
# 0                Recebi bem antes do prazo estipulado.
# 1    Parabéns lojas lannister adorei comprar pela I...
# 2    aparelho eficiente. no site a marca do aparelh...
# 3      Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 4    Vendedor confiável, produto ok e entrega antes...
# Name: review_comment_message, dtype: object

# %%
reviews_cleaned.tail()
# Out:
# 41426    Entregou dentro do prazo. O produto chegou em ...
# 41427    O produto não foi enviado com NF, não existe v...
# 41428    Excelente mochila, entrega super rápida. Super...
# 41429    Solicitei a compra de uma capa de retrovisor c...
# 41430    meu produto chegou e ja tenho que devolver, po...
# Name: review_comment_message, dtype: object

# %%
# Extraemos cada fila de la columna reviews_message en una lista para facilitar limpieza
texto = []

for fila in reviews_cleaned:
    texto.append(fila)

# %%
# Convertimos cada palabra en cada una de las listas en minuscula para facilitar analisis
texto = [palabra.lower() for palabra in texto]

# %%
# Eliminamos numeros y caracteres especiales
texto_limpio = []

for palabra in texto:
    palabra = re.sub(r"[\W\d]", " ", palabra)
    texto_limpio.append(palabra.strip())

# %%
len(texto_limpio)
# Out:
# 41431

# %%
texto = []

for palabra in texto_limpio:
    palabra = palabra.split()
    texto.append(palabra)

# %%
texto[0]
# Out:
# ['recebi', 'bem', 'antes', 'do', 'prazo', 'estipulado']

# %%
# Creamos una funcion para convertir una lista en un string
def listToString(lista):
    string = " "
    return string.join(lista)

# %%
# Extraemos las palabras vacias cada lista dentro de texto, y luego
# convertimos nuevamente esa lista en un string

pre_procesado = []
for lista in texto:
    lista = [word for word in lista if word not in stopwords_ptg]
    lista = listToString(lista)    
    pre_procesado.append(lista)

# %%
pre_procesado[0]
# Out:
# 'recebi bem antes prazo estipulado'

# %%
reviews_pre = pd.DataFrame({"reviews_pre": pre_procesado})

# %%
reviews["review_procesed"] = reviews_pre

# %%
reviews
# Out:
#                               review_id                          order_id  \
# 0      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 1      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 2      8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3      4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 4      3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# ...                                 ...                               ...
# 41426  df5fae90e85354241d5d64a8955b2b09  509b86c65fe4e2ad5b96408cfef9755e
# 41427  a709d176f59bc3af77f4149c96bae357  d5cb12269711bd1eaf7eed8fd32a7c95
# 41428  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 41429  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 41430  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 5                  NaN
# 1                 5                  NaN
# 2                 4            recomendo
# 3                 4                  NaN
# 4                 5      Super recomendo
# ...             ...                  ...
# 41426             5                  NaN
# 41427             3                  NaN
# 41428             5                  NaN
# 41429             1                  NaN
# 41430             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 1      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# 2      aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 3        Mas um pouco ,travando...pelo valor ta Boa.\r\n  2018-02-16 00:00:00
# 4      Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
# ...                                                  ...                  ...
# 41426  Entregou dentro do prazo. O produto chegou em ...  2018-02-07 00:00:00
# 41427  O produto não foi enviado com NF, não existe v...  2018-05-19 00:00:00
# 41428  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 41429  Solicitei a compra de uma capa de retrovisor c...  2017-12-15 00:00:00
# 41430  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp  \
# 0         2017-04-21 22:02:06
# 1         2018-03-02 10:26:53
# 2         2018-05-23 16:45:47
# 3         2018-02-20 10:52:22
# 4         2018-05-24 03:00:01
# ...                       ...
# 41426     2018-02-19 19:47:23
# 41427     2018-05-20 21:51:06
# 41428     2018-03-23 09:10:43
# 41429     2017-12-16 01:29:43
# 41430     2017-07-03 21:01:49
#
#                                          review_procesed
# 0                      recebi bem antes prazo estipulado
# 1      parabéns lojas lannister adorei comprar intern...
# 2      aparelho eficiente site marca aparelho impress...
# 3                            pouco travando valor ta boa
# 4      vendedor confiável produto ok entrega antes prazo
# ...                                                  ...
# 41426  entregou dentro prazo produto chegou condições...
# 41427  produto enviado nf existe venda nf certeza fic...
# 41428  excelente mochila entrega super rápida super r...
# 41429  solicitei compra capa retrovisor celta prisma ...
# 41430  produto chegou ja devolver pois defeito segura...
#
# [41431 rows x 8 columns]

# %%
palabras_totales = reviews["review_procesed"]

words = []

for word in palabras_totales:
    lista = word.split()
    for palabra in lista:
        words.append(palabra)

# %%
frecuencia_de_palabras = pd.Series(words)
palabras_totales = frecuencia_de_palabras.value_counts()

# %%
palabras_totales = palabras_totales.reset_index()
palabras_totales = palabras_totales.rename(columns = {"index": "Palabras", 0: "Frecuencia"})

# %%
palabras_totales.iloc[12122]
# Out:
# Palabras      __
# Frecuencia     1
# Name: 12122, dtype: object

# %%
import spacy

# %%
nlp = spacy.load("pt_core_news_sm")

# %%
freq = palabras_totales["Palabras"].tolist()

# %%
freq[12122]
# Out:
# '__'

# %%
tokens = []
for word in freq:
    token = nlp(word)
    for tok in token:
        tokens.append(tok)

# %%
pos = []
lemma = []

for token in tokens:
    pos.append(token.pos_)
    lemma.append(token.lemma_)

# %%
print(tokens[4], tokens[4].pos_, tokens[4].lemma_)
# Out:
# chegou VERB chegar

# %%
pos[12122]
# Out:
# 'PROPN'

# %%
pos_df = pd.DataFrame(pos, columns=["POS"])
pos_df.iloc[12122]
# Out:
# POS    PROPN
# Name: 12122, dtype: object

# %%
lemma_df = pd.DataFrame(lemma, columns=["Lemma"])
lemma_df.iloc[12122]
# Out:
# Lemma    _
# Name: 12122, dtype: object

# %%
df = palabras_totales.merge(pos_df, left_index=True, right_index=True)

# %%
df = df.merge(lemma_df, left_index=True, right_index=True)

# %%
df.to_csv("palabras_pt.csv", index=False)

# %%
df
# Out:
#            Palabras  Frecuencia   POS      Lemma_x      Lemma_y
# 0           produto       18722  NOUN      produto      produto
# 1             prazo        8497  NOUN        prazo        prazo
# 2           entrega        6633  VERB     entregar     entregar
# 3             antes        5634   ADV        antar        antar
# 4            chegou        5610  VERB       chegar       chegar
# ...             ...         ...   ...          ...          ...
# 15382  confortáveis           1  VERB     repensar     repensar
# 15383      ranhuras           1  NOUN  confortável  confortável
# 15384       ingerir           1  NOUN      ranhura      ranhura
# 15385    estabiliza           1  VERB      ingerir      ingerir
# 15386    esfarelada           1  VERB  estabilizar  estabilizar
#
# [15387 rows x 5 columns]

# %%
df.iloc[12121]
# Out:
# Palabras      petfeitas
# Frecuencia            1
# POS                NOUN
# Lemma_x       petfeitas
# Lemma_y       petfeitas
# Name: 12121, dtype: object
